# %%
import torch
import PIL
from PIL import Image, ImageEnhance
import os

# %%
path = "/home/naxos2-raid25/kneel027/home/kneel027/Second-Sight/output/mental_imagery_paper_b3/imagery/subj01_40sess_hypatia_ridge_sc3/subject1/"
index = 1
low_level = Image.open(f"{path}/{index}/low_level.png")
low_level
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
# Blur/smooth the image
blurred_image = low_level.filter(PIL.ImageFilter.GaussianBlur(7))

# Enhance the contrast of the blurred image
enhanced_image = ImageEnhance.Contrast(blurred_image).enhance(1.5)
# enhanced_image = enhancer.enhance(1.5)  # Increase contrast by a factor of 2
blurred_image
enhanced_image
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
